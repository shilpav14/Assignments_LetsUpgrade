# %%
# Question 1:

import pandas as pd

# %%
# Checking the version

print(pd.__version__)
# Out:
# 1.0.5

# %%
# Question 2:

import numpy as np

# Create a numpy array
np_array = np.array(['A','B','C','D','E','F'])
print("Numpy Array: ", np_array)

# Create a series from a numpy array

numpy_series = pd.Series(np_array)
print("Series:\n")
print(numpy_series)
# Out:
# Numpy Array:  ['A' 'B' 'C' 'D' 'E' 'F']
# Series:
#
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E
# 5    F
# dtype: object

# %%
# Question 3:

data = pd.DataFrame({'Name':['Bob','Cam','Sham','Gupta'],'Age':[25,30,28,39],'Salary':[96000,56000,25000,85000],'Spending':[2000,5000,10000,5600]})
data
# Out:
#     Name  Age  Salary  Spending
# 0    Bob   25   96000      2000
# 1    Cam   30   56000      5000
# 2   Sham   28   25000     10000
# 3  Gupta   39   85000      5600

# %%
# Changing the index to column

data.reset_index(level = 0, inplace = True)
data
# Out:
#    index   Name  Age  Salary  Spending
# 0      0    Bob   25   96000      2000
# 1      1    Cam   30   56000      5000
# 2      2   Sham   28   25000     10000
# 3      3  Gupta   39   85000      5600

# %%
# Questionabs 4:

import seaborn as sns

# Getting all datasets from the seaborn library
sns.get_dataset_names()
# Out:
# C:\Users\shilpa v gowda\anaconda3\lib\site-packages\seaborn\utils.py:384: GuessedAtParserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 384 of the file C:\Users\shilpa v gowda\anaconda3\lib\site-packages\seaborn\utils.py. To get rid of this warning, pass the additional argument 'features="lxml"' to the BeautifulSoup constructor.
#
#   gh_list = BeautifulSoup(http)
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
# Loading the 'mpg' dataset using seaborn library

data = sns.load_dataset('mpg')

# %%
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
data.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
data.tail()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin             name
# 393          82     usa  ford mustang gl
# 394          82  europe        vw pickup
# 395          82     usa    dodge rampage
# 396          82     usa      ford ranger
# 397          82     usa       chevy s-10

# %%
data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model_year', 'origin', 'name'],
#       dtype='object')

# %%
data.shape
# Out:
# (398, 9)

# %%
data.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
data.isna().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower       True
# weight          False
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
data.horsepower.unique()
# Out:
# array([130., 165., 150., 140., 198., 220., 215., 225., 190., 170., 160.,
#         95.,  97.,  85.,  88.,  46.,  87.,  90., 113., 200., 210., 193.,
#         nan, 100., 105., 175., 153., 180., 110.,  72.,  86.,  70.,  76.,
#         65.,  69.,  60.,  80.,  54., 208., 155., 112.,  92., 145., 137.,
#        158., 167.,  94., 107., 230.,  49.,  75.,  91., 122.,  67.,  83.,
#         78.,  52.,  61.,  93., 148., 129.,  96.,  71.,  98., 115.,  53.,
#         81.,  79., 120., 152., 102., 108.,  68.,  58., 149.,  89.,  63.,
#         48.,  66., 139., 103., 125., 133., 138., 135., 142.,  77.,  62.,
#        132.,  84.,  64.,  74., 116.,  82.])

# %%
data = data[data.horsepower != 'nan']
# Out:
# C:\Users\shilpa v gowda\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)

# %%
data.shape
# Out:
# (398, 9)

# %%
print('nan' in data.horsepower)
# Out:
# False

# %%
data.shape
# Out:
# (398, 9)

# %%
data.horsepower = data.horsepower.astype('float')
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
# Describing 'mpg'

data.mpg.describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
data.horsepower = data.horsepower.astype('float')
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower      float64
# weight            int64
# acceleration    float64
# model_year        int64
# origin           object
# name             object
# dtype: object

# %%
sns.distplot(data['mpg'])

# %%
# Using scale() function

def scale(a):
    b = (a-a.min())/(a.max()-a.min())
    return b

# %%
# All our data is now scaled to the same range of [0,1]

data_scale = data.copy()

# %%
data_scale ['displacement'] = scale(data_scale['displacement'])
data_scale['horsepower'] = scale(data_scale['horsepower'])
data_scale ['acceleration'] = scale(data_scale['acceleration'])
data_scale ['weight'] = scale(data_scale['weight'])
data_scale['mpg'] = scale(data_scale['mpg'])

# %%
data_scale.head()
# Out:
#         mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0  0.239362          8      0.617571    0.456522  0.536150      0.238095
# 1  0.159574          8      0.728682    0.646739  0.589736      0.208333
# 2  0.239362          8      0.645995    0.565217  0.516870      0.178571
# 3  0.186170          8      0.609819    0.565217  0.516019      0.238095
# 4  0.212766          8      0.604651    0.510870  0.520556      0.148810
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
data_scale.head()
# Out:
#         mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0  0.239362          8      0.617571    0.456522  0.536150      0.238095
# 1  0.159574          8      0.728682    0.646739  0.589736      0.208333
# 2  0.239362          8      0.645995    0.565217  0.516870      0.178571
# 3  0.186170          8      0.609819    0.565217  0.516019      0.238095
# 4  0.212766          8      0.604651    0.510870  0.520556      0.148810
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
data['Country_code'] = data.origin.replace([1,2,3],['USA','Europe','Japan'])
data.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name Country_code
# 0          70    usa  chevrolet chevelle malibu          usa
# 1          70    usa          buick skylark 320          usa
# 2          70    usa         plymouth satellite          usa
# 3          70    usa              amc rebel sst          usa
# 4          70    usa                ford torino          usa

# %%
data_scale['Country_code'] = data.origin.replace([1,2,3],['USA','Europe','Japan'])

# %%
data_scale.head()
# Out:
#         mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0  0.239362          8      0.617571    0.456522  0.536150      0.238095
# 1  0.159574          8      0.728682    0.646739  0.589736      0.208333
# 2  0.239362          8      0.645995    0.565217  0.516870      0.178571
# 3  0.186170          8      0.609819    0.565217  0.516019      0.238095
# 4  0.212766          8      0.604651    0.510870  0.520556      0.148810
#
#    model_year origin                       name Country_code
# 0          70    usa  chevrolet chevelle malibu          usa
# 1          70    usa          buick skylark 320          usa
# 2          70    usa         plymouth satellite          usa
# 3          70    usa              amc rebel sst          usa
# 4          70    usa                ford torino          usa

# %%
# Question 5 :

import matplotlib.pyplot as plt
var = 'Country_code'
data_plt = pd.concat([data_scale['mpg'], data_scale[var]], axis=1)
f, ax = plt.subplots(figsize=(8, 6))
fig = sns.boxplot(x=var, y="mpg", data=data_plt)

plt.axhline(data_scale.mpg.mean(),color='r',linestyle='dashed',linewidth=2)

# %% [markdown]
# #### The red line marks represents the average of the test.
#
# ## Observations :-
#
# Majorty of the cars from USA (i.e., almost 75%) have mpg below global average
# Majorty of the cars from Japan and Europe have mpg above global average.

# %%
# # Using regular expression to extract the company names

# data[data.index.str.contains('subaru')].index.str.replace('(.*)', 'subaru dl')

# %%
# Question 6:
var = 'Country_code'
data[data[var]== data[var].min()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 19   26.0          4          97.0        46.0    1835          20.5
# 20   25.0          4         110.0        87.0    2672          17.5
# 21   24.0          4         107.0        90.0    2430          14.5
# 22   25.0          4         104.0        95.0    2375          17.5
# 23   26.0          4         121.0       113.0    2234          12.5
# ..    ...        ...           ...         ...     ...           ...
# 354  34.5          4         100.0         NaN    2320          15.8
# 359  28.1          4         141.0        80.0    3230          20.4
# 360  30.7          6         145.0        76.0    3160          19.6
# 375  36.0          4         105.0        74.0    1980          15.3
# 394  44.0          4          97.0        52.0    2130          24.6
#
#      model_year  origin                          name Country_code
# 19           70  europe  volkswagen 1131 deluxe sedan       europe
# ...

# %%
x = data.groupby(['name', 'Country_code']).agg('max')
x.head()
# Out:
#                                        mpg  cylinders  displacement  \
# name                    Country_code
# amc ambassador brougham usa           13.0          8         360.0
# amc ambassador dpl      usa           15.0          8         390.0
# amc ambassador sst      usa           17.0          8         304.0
# amc concord             usa           24.3          6         232.0
# amc concord d/l         usa           18.1          6         258.0
#
#                                       horsepower  weight  acceleration  \
# name                    Country_code
# amc ambassador brougham usa                175.0    3821          11.0
# amc ambassador dpl      usa                190.0    3850           8.5
# amc ambassador sst      usa                150.0    3672          11.5
# amc concord             usa                 90.0    3210          20.1
# amc concord d/l         usa                120.0    3410          15.1
#
# ...
